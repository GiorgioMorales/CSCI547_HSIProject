# %% [markdown]
# # Prepare tensorflow-model-optimization

# %%
! pip uninstall -y tensorflow
! pip uninstall -y tf-nightly
! pip install -U tensorflow-gpu==1.14.0

! pip install tensorflow-model-optimization
# Out:
# Uninstalling tensorflow-1.15.0:
#   Successfully uninstalled tensorflow-1.15.0
# WARNING: Skipping tf-nightly as it is not installed.
# Collecting tensorflow-gpu==1.14.0
#   Downloading https://files.pythonhosted.org/packages/76/04/43153bfdfcf6c9a4c38ecdb971ca9a75b9a791bb69a764d652c359aca504/tensorflow_gpu-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (377.0MB)
#      |████████████████████████████████| 377.0MB 41kB/s
# Requirement already satisfied, skipping upgrade: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (0.9.0)
# Requirement already satisfied, skipping upgrade: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (0.2.2)
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.27.1)
# Requirement already satisfied, skipping upgrade: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.17.5)
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (3.10.0)
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
#      |████████████████████████████████| 491kB 32.0MB/s
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.12.0)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.1.0)
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.11.2)
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.2MB 38.1MB/s
# Requirement already satisfied, skipping upgrade: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (0.8.1)
# Requirement already satisfied, skipping upgrade: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (0.1.8)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.1.0)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.0.8)
# Requirement already satisfied, skipping upgrade: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (0.34.2)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==1.14.0) (45.2.0)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (1.0.0)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (3.2.1)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==1.14.0) (2.8.0)
# Installing collected packages: tensorflow-estimator, tensorboard, tensorflow-gpu
#   Found existing installation: tensorflow-estimator 1.15.1
#     Uninstalling tensorflow-estimator-1.15.1:
#       Successfully uninstalled tensorflow-estimator-1.15.1
#   Found existing installation: tensorboard 1.15.0
#     Uninstalling tensorboard-1.15.0:
#       Successfully uninstalled tensorboard-1.15.0
# Successfully installed tensorboard-1.14.0 tensorflow-estimator-1.14.0 tensorflow-gpu-1.14.0
# Collecting tensorflow-model-optimization
#   Downloading https://files.pythonhosted.org/packages/8f/c4/4c3d011e432bd9c19f0323f7da7d3f783402615e4c3b5a98416c7da9cb05/tensorflow_model_optimization-0.2.1-py2.py3-none-any.whl (93kB)
#      |████████████████████████████████| 102kB 3.2MB/s
# Requirement already satisfied: numpy~=1.14 in /usr/local/lib/python3.6/dist-packages (from tensorflow-model-optimization) (1.17.5)
# Collecting enum34~=1.1
#   Downloading https://files.pythonhosted.org/packages/df/6e/46a0304561a07bda942c4283b67228d5b87d1ebd1189c866ede4b4cd6a0a/enum34-1.1.9-py3-none-any.whl
# Requirement already satisfied: six~=1.10 in /usr/local/lib/python3.6/dist-packages (from tensorflow-model-optimization) (1.12.0)
# Installing collected packages: enum34, tensorflow-model-optimization
# Successfully installed enum34-1.1.9 tensorflow-model-optimization-0.2.1

# %%
# %load_ext tensorboard
import tensorboard
import tensorflow as tf
tf.enable_eager_execution()

import tempfile
import zipfile
import os
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# #Download dataset from Google Drive

# %%
# !pip install PyDrive
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
# Out:
# Requirement already satisfied: PyDrive in /usr/local/lib/python3.6/dist-packages (1.3.1)
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (1.7.11)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (4.1.3)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (3.13)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.11.3)
# Requirement already satisfied: six<2dev,>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.12.0)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.7.2)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.0.3)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (3.0.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.2.8)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (4.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.4.8)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client>=1.2->PyDrive) (45.2.0)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client>=1.2->PyDrive) (3.1.1)

# %%
# https://drive.google.com/open?id=1Wz2xqSZSjLDzXXTLdkf6zyTUUcBopn3i
download = drive.CreateFile({'id': '1Wz2xqSZSjLDzXXTLdkf6zyTUUcBopn3i'})
download.GetContentFile('avocado_dataset_w64.hdf5')

# %% [markdown]
# # Read Dataset

# %%
from sklearn.model_selection import StratifiedKFold
import numpy as np
from operator import truediv
import h5py
from sklearn.decomposition import PCA
from sklearn.metrics import precision_recall_fscore_support, accuracy_score, cohen_kappa_score, confusion_matrix

import tensorboard
import tensorflow as tf
tf.enable_eager_execution()

import tempfile
import zipfile
import os
import cv2

"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""
""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""
Data augmentation functions
""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""
"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""
def add_rotation_flip(x, y):

    x = np.reshape(x, (x.shape[0], x.shape[1], x.shape[2], x.shape[3], 1))

    # Flip horizontally
    x_h = np.flip(x[:, :, :, :, :], 1)
    # Flip vertically
    x_v = np.flip(x[:, :, :, :, :], 2)
    # Flip horizontally and vertically
    x_hv = np.flip(x_h[:, :, :, :, :], 2)

    # Concatenate
    x = np.concatenate((x, x_h, x_v, x_hv))
    y = np.concatenate((y, y, y, y))

    return x, y
    
"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""
""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""
LOAD HDF5 FILE
""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""
"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""

hdf5_file = h5py.File('avocado_dataset_w64.hdf5', "r")
train_x = np.array(hdf5_file["train_img"][...])
train_y = np.array(hdf5_file["train_labels"][...])

# Average consecutive bands
img2 = np.zeros((train_x.shape[0], int(train_x.shape[1]/2), int(train_x.shape[2]/2), int(train_x.shape[3] / 2)))
for n in range(0, train_x.shape[0]):
    xt = cv2.resize(np.float32(train_x[n, :, :, :]), (32, 32), interpolation=cv2.INTER_CUBIC)
    for i in range(0, train_x.shape[3], 2):
        img2[n, :, :, int(i / 2)] = (xt[:, :, i] + xt[:, :, i + 1]) / 2.

train_x = img2

train_x, train_y = add_rotation_flip(train_x, train_y)

print(train_x.shape)
# Out:
# (964, 32, 32, 150, 1)

# %% [markdown]
# # Calculate loss after removing one spectral band

# %%
data = 'AVOCADO'
windowSize = train_x.shape[1]
classes = 2

tf.keras.backend.clear_session()
# Load trained pruned network
#loaded_model = tf.keras.models.load_model("Kochia_hyper3DNet_pruned.h5")

# Load model without pruning
loaded_model = tf.keras.models.load_model("weights-hyper3dnetAVOCADO1-best_3layers_4filters.h5")

loaded_model.compile(
        loss=tf.keras.losses.binary_crossentropy,
        optimizer='adadelta',
        metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
import pickle
from tensorflow_model_optimization.sparsity import keras as sparsity

windowSize = train_x.shape[1]
classes = 2
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=7)

epochs = 8
batch_size = 32;
num_train_samples = train_x.shape[0]
end_step = np.ceil(1.0 * num_train_samples / batch_size).astype(np.int32) * epochs

data = 'AVOCADO'
SA = np.zeros((10, train_x.shape[3],))
ntrain = 1
for train, test in kfold.split(train_x, train_y):

    new_pruning_params = {
          'pruning_schedule': sparsity.PolynomialDecay(initial_sparsity=0.05,
                                                      final_sparsity=0.1,
                                                      begin_step=0,
                                                      end_step=end_step,
                                                      frequency=100)
    }
    new_pruned_model = sparsity.prune_low_magnitude(loaded_model, **new_pruning_params)
    new_pruned_model.load_weights("pruned-weights-hyper3dnet" + data + str(ntrain) + "-best_3layers_4filters.h5")
    loaded_model.compile(
        loss=tf.keras.losses.binary_crossentropy,
        optimizer='adadelta',
        metrics=['accuracy'])

    ytest = train_y[test] 
    ypred1 = new_pruned_model.predict(train_x[test])
    ypred1 = ypred1.round()
    loss1 = tf.keras.losses.binary_crossentropy(ytest, ypred1)
    print("Fold:" + str(ntrain) +" , original accuracy: " + str(np.sum(ypred1.transpose()==ytest)/len(ytest)))
    for nchannel in range(0, train_x.shape[3]):
      xtest = train_x[test].copy()
      xtest[:, :, :, nchannel, :] = np.zeros((train_x[test].shape[0], train_x.shape[1], train_x.shape[2], 1))
      ypred2 = new_pruned_model.predict(xtest)
      ypred2 = ypred2.round()
      loss2 = tf.keras.losses.binary_crossentropy(ytest, ypred2)
      print("Analyzing channel " +str(nchannel) + ": " + str(np.sum(ypred2.transpose()==ytest)/len(ytest)))
      SA[ntrain-1][nchannel] = np.sum(abs(loss2 - loss1))

    with open('SA_fold_pruning'+str(ntrain), 'wb') as f:
      pickle.dump(SA[ntrain-1], f)

    ntrain += 1;
# Out:
# Fold:1 , original accuracy: 1.0
# Analyzing channel 0: 0.7938144329896907
# Analyzing channel 1: 0.9690721649484536
# Analyzing channel 2: 0.979381443298969
# Analyzing channel 3: 1.0
# Analyzing channel 4: 1.0
# Analyzing channel 5: 1.0
# Analyzing channel 6: 0.9587628865979382
# Analyzing channel 7: 1.0
# Analyzing channel 8: 1.0
# Analyzing channel 9: 1.0
# Analyzing channel 10: 1.0
# Analyzing channel 11: 0.9484536082474226
# Analyzing channel 12: 0.9896907216494846
# Analyzing channel 13: 0.979381443298969
# Analyzing channel 14: 0.9690721649484536
# Analyzing channel 15: 0.9896907216494846
# Analyzing channel 16: 0.979381443298969
# Analyzing channel 17: 0.979381443298969
# Analyzing channel 18: 1.0
# Analyzing channel 19: 1.0
# Analyzing channel 20: 0.6391752577319587
# Analyzing channel 21: 0.6907216494845361
# Analyzing channel 22: 0.5670103092783505
# Analyzing channel 23: 0.9896907216494846
# Analyzing channel 24: 0.6185567010309279
# Analyzing channel 25: 0.8865979381443299
# Analyzing channel 26: 0.9278350515463918
# Analyzing channel 27: 0.8247422680412371
# Analyzing channel 28: 0.9896907216494846
# Analyzing channel 29: 0.9896907216494846
# Analyzing channel 30: 1.0
# Analyzing channel 31: 0.979381443298969
# Analyzing channel 32: 0.9896907216494846
# Analyzing channel 33: 0.9896907216494846
# Analyzing channel 34: 0.979381443298969
# Analyzing channel 35: 0.9381443298969072
# Analyzing channel 36: 0.8762886597938144
# Analyzing channel 37: 1.0
# Analyzing channel 38: 1.0
# Analyzing channel 39: 1.0
# Analyzing channel 40: 0.979381443298969
# Analyzing channel 41: 0.9278350515463918
# Analyzing channel 42: 0.9690721649484536
# Analyzing channel 43: 0.6907216494845361
# Analyzing channel 44: 0.9690721649484536
# Analyzing channel 45: 0.9587628865979382
# Analyzing channel 46: 1.0
# Analyzing channel 47: 1.0
# Analyzing channel 48: 0.8865979381443299
# Analyzing channel 49: 0.7835051546391752
# Analyzing channel 50: 0.8865979381443299
# Analyzing channel 51: 0.6907216494845361
# Analyzing channel 52: 0.8556701030927835
# Analyzing channel 53: 1.0
# Analyzing channel 54: 1.0
# Analyzing channel 55: 0.979381443298969
# Analyzing channel 56: 1.0
# Analyzing channel 57: 1.0
# Analyzing channel 58: 0.979381443298969
# Analyzing channel 59: 1.0
# Analyzing channel 60: 0.865979381443299
# Analyzing channel 61: 0.8762886597938144
# Analyzing channel 62: 0.9587628865979382
# Analyzing channel 63: 0.8556701030927835
# Analyzing channel 64: 0.845360824742268
# Analyzing channel 65: 0.9896907216494846
# Analyzing channel 66: 0.7731958762886598
# Analyzing channel 67: 0.7938144329896907
# Analyzing channel 68: 1.0
# Analyzing channel 69: 0.7835051546391752
# Analyzing channel 70: 0.7938144329896907
# Analyzing channel 71: 0.865979381443299
# Analyzing channel 72: 0.5670103092783505
# Analyzing channel 73: 0.5567010309278351
# Analyzing channel 74: 0.865979381443299
# Analyzing channel 75: 0.9690721649484536
# Analyzing channel 76: 1.0
# Analyzing channel 77: 1.0
# Analyzing channel 78: 1.0
# Analyzing channel 79: 1.0
# Analyzing channel 80: 1.0
# Analyzing channel 81: 1.0
# Analyzing channel 82: 0.9896907216494846
# Analyzing channel 83: 1.0
# Analyzing channel 84: 0.9484536082474226
# Analyzing channel 85: 0.9484536082474226
# Analyzing channel 86: 1.0
# Analyzing channel 87: 1.0
# Analyzing channel 88: 0.7731958762886598
# Analyzing channel 89: 0.8969072164948454
# Analyzing channel 90: 0.7422680412371134
# Analyzing channel 91: 0.8762886597938144
# Analyzing channel 92: 0.9690721649484536
# Analyzing channel 93: 1.0
# Analyzing channel 94: 1.0
# Analyzing channel 95: 1.0
# Analyzing channel 96: 1.0
# Analyzing channel 97: 1.0
# Analyzing channel 98: 1.0
# Analyzing channel 99: 1.0
# Analyzing channel 100: 1.0
# Analyzing channel 101: 0.979381443298969
# Analyzing channel 102: 1.0
# Analyzing channel 103: 0.9896907216494846
# Analyzing channel 104: 1.0
# Analyzing channel 105: 1.0
# Analyzing channel 106: 1.0
# Analyzing channel 107: 1.0
# Analyzing channel 108: 1.0
# Analyzing channel 109: 1.0
# Analyzing channel 110: 1.0
# Analyzing channel 111: 1.0
# Analyzing channel 112: 1.0
# Analyzing channel 113: 0.9896907216494846
# Analyzing channel 114: 1.0
# Analyzing channel 115: 0.5051546391752577
# Analyzing channel 116: 0.8350515463917526
# Analyzing channel 117: 0.5257731958762887
# Analyzing channel 118: 0.5257731958762887
# Analyzing channel 119: 0.979381443298969
# Analyzing channel 120: 1.0
# Analyzing channel 121: 0.5154639175257731
# Analyzing channel 122: 0.9690721649484536
# Analyzing channel 123: 0.5360824742268041
# Analyzing channel 124: 0.6804123711340206
# Analyzing channel 125: 0.7010309278350515
# Analyzing channel 126: 1.0
# Analyzing channel 127: 0.8350515463917526
# Analyzing channel 128: 0.9175257731958762
# Analyzing channel 129: 0.9690721649484536
# Analyzing channel 130: 0.5979381443298969
# Analyzing channel 131: 1.0
# Analyzing channel 132: 0.7731958762886598
# Analyzing channel 133: 0.865979381443299
# Analyzing channel 134: 0.9072164948453608
# Analyzing channel 135: 1.0
# Analyzing channel 136: 0.6288659793814433
# Analyzing channel 137: 0.9381443298969072
# Analyzing channel 138: 0.5463917525773195
# Analyzing channel 139: 0.5051546391752577
# Analyzing channel 140: 0.8762886597938144
# Analyzing channel 141: 0.7731958762886598
# Analyzing channel 142: 0.5257731958762887
# Analyzing channel 143: 0.5257731958762887
# Analyzing channel 144: 0.6804123711340206
# Analyzing channel 145: 0.5360824742268041
# Analyzing channel 146: 0.7628865979381443
# Analyzing channel 147: 0.7216494845360825
# Analyzing channel 148: 0.5154639175257731
# Analyzing channel 149: 0.5979381443298969
# Fold:2 , original accuracy: 1.0
# Analyzing channel 0: 0.979381443298969
# Analyzing channel 1: 1.0
# Analyzing channel 2: 1.0
# Analyzing channel 3: 0.9587628865979382
# Analyzing channel 4: 0.9690721649484536
# Analyzing channel 5: 1.0
# Analyzing channel 6: 0.9896907216494846
# Analyzing channel 7: 0.9896907216494846
# Analyzing channel 8: 1.0
# Analyzing channel 9: 0.9896907216494846
# Analyzing channel 10: 0.9278350515463918
# Analyzing channel 11: 0.9381443298969072
# Analyzing channel 12: 0.9278350515463918
# Analyzing channel 13: 0.979381443298969
# Analyzing channel 14: 0.8041237113402062
# Analyzing channel 15: 1.0
# Analyzing channel 16: 1.0
# Analyzing channel 17: 0.979381443298969
# Analyzing channel 18: 0.979381443298969
# Analyzing channel 19: 0.979381443298969
# Analyzing channel 20: 0.8865979381443299
# Analyzing channel 21: 0.9690721649484536
# Analyzing channel 22: 0.979381443298969
# Analyzing channel 23: 0.4742268041237113
# Analyzing channel 100: 1.0
# Analyzing channel 101: 1.0
# Analyzing channel 102: 1.0
# Analyzing channel 103: 1.0
# Analyzing channel 104: 0.9896907216494846
# Analyzing channel 105: 1.0
# Analyzing channel 106: 0.9896907216494846
# Analyzing channel 107: 1.0
# Analyzing channel 108: 1.0
# Analyzing channel 109: 0.9896907216494846
# Analyzing channel 110: 1.0
# Analyzing channel 111: 1.0
# Analyzing channel 112: 1.0
# Analyzing channel 113: 1.0
# Analyzing channel 114: 1.0
# Analyzing channel 115: 1.0
# Analyzing channel 116: 0.9896907216494846
# Analyzing channel 117: 0.9381443298969072
# Analyzing channel 118: 0.9587628865979382
# Analyzing channel 119: 0.7010309278350515
# Analyzing channel 120: 0.9484536082474226
# Analyzing channel 121: 0.9484536082474226
# Analyzing channel 122: 0.9072164948453608
# Analyzing channel 123: 0.8247422680412371
# Analyzing channel 124: 0.9587628865979382
# Analyzing channel 125: 0.7422680412371134
# Analyzing channel 126: 0.711340206185567
# Analyzing channel 127: 1.0
# Analyzing channel 128: 0.9278350515463918
# Analyzing channel 129: 0.865979381443299
# Analyzing channel 130: 0.8865979381443299
# Analyzing channel 131: 0.5360824742268041
# Analyzing channel 132: 0.8144329896907216
# Analyzing channel 133: 0.9175257731958762
# Analyzing channel 134: 0.8247422680412371
# Analyzing channel 135: 0.7422680412371134
# Analyzing channel 136: 0.9072164948453608
# Analyzing channel 137: 0.5257731958762887
# Analyzing channel 138: 0.7010309278350515
# Analyzing channel 139: 0.6082474226804123
# Analyzing channel 140: 0.4948453608247423
# Analyzing channel 141: 0.5257731958762887
# Analyzing channel 142: 0.5257731958762887
# Analyzing channel 143: 0.5257731958762887
# Analyzing channel 144: 0.7525773195876289
# Analyzing channel 145: 0.4845360824742268
# Analyzing channel 146: 0.5773195876288659
# Analyzing channel 147: 0.4845360824742268
# Analyzing channel 148: 0.4845360824742268
# Analyzing channel 149: 0.4845360824742268
# Fold:3 , original accuracy: 1.0
# Analyzing channel 0: 0.8969072164948454
# Analyzing channel 1: 1.0
# Analyzing channel 2: 1.0
# Analyzing channel 3: 1.0
# Analyzing channel 4: 0.979381443298969
# Analyzing channel 5: 1.0
# Analyzing channel 6: 1.0
# Analyzing channel 7: 1.0
# Analyzing channel 8: 1.0
# Analyzing channel 9: 1.0
# Analyzing channel 10: 0.9896907216494846
# Analyzing channel 11: 1.0
# Analyzing channel 12: 1.0
# Analyzing channel 13: 1.0
# Analyzing channel 14: 0.9896907216494846
# Analyzing channel 15: 0.9896907216494846
# Analyzing channel 16: 1.0
# Analyzing channel 17: 1.0
# Analyzing channel 18: 1.0
# Analyzing channel 19: 0.9896907216494846
# Analyzing channel 20: 1.0
# Analyzing channel 21: 1.0
# Analyzing channel 22: 1.0
# Analyzing channel 23: 0.9896907216494846
# Analyzing channel 24: 0.9587628865979382
# Analyzing channel 25: 1.0
# Analyzing channel 26: 1.0
# Analyzing channel 27: 1.0
# Analyzing channel 28: 0.9896907216494846
# Analyzing channel 29: 0.9896907216494846
# Analyzing channel 30: 0.9896907216494846
# Analyzing channel 31: 1.0
# Analyzing channel 32: 1.0
# Analyzing channel 33: 0.979381443298969
# Analyzing channel 34: 0.9896907216494846
# Analyzing channel 35: 0.9896907216494846
# Analyzing channel 36: 0.9896907216494846
# Analyzing channel 37: 0.9896907216494846
# Analyzing channel 38: 1.0
# Analyzing channel 39: 1.0
# Analyzing channel 40: 0.9896907216494846
# Analyzing channel 41: 0.9896907216494846
# Analyzing channel 42: 0.979381443298969
# Analyzing channel 43: 1.0
# Analyzing channel 44: 0.9896907216494846
# Analyzing channel 45: 0.8556701030927835
# Analyzing channel 46: 0.9484536082474226
# Analyzing channel 47: 1.0
# Analyzing channel 48: 1.0
# Analyzing channel 49: 0.9896907216494846
# Analyzing channel 50: 0.8762886597938144
# Analyzing channel 51: 0.8969072164948454
# Analyzing channel 52: 0.9587628865979382
# Analyzing channel 53: 0.979381443298969
# Analyzing channel 54: 1.0
# Analyzing channel 55: 1.0
# Analyzing channel 56: 1.0
# Analyzing channel 57: 0.9896907216494846
# Analyzing channel 58: 1.0
# Analyzing channel 59: 0.9896907216494846
# Analyzing channel 60: 0.9896907216494846
# Analyzing channel 61: 0.979381443298969
# Analyzing channel 62: 0.9690721649484536
# Analyzing channel 63: 0.979381443298969
# Analyzing channel 64: 0.979381443298969
# Analyzing channel 65: 0.9896907216494846
# Analyzing channel 66: 1.0
# Analyzing channel 67: 0.979381443298969
# Analyzing channel 68: 0.9587628865979382
# Analyzing channel 69: 0.9175257731958762
# Analyzing channel 70: 0.979381443298969
# Analyzing channel 71: 0.9896907216494846
# Analyzing channel 72: 0.979381443298969
# Analyzing channel 73: 1.0
# Analyzing channel 74: 1.0
# Analyzing channel 75: 0.845360824742268
# Analyzing channel 76: 0.9278350515463918
# Analyzing channel 77: 0.979381443298969
# Analyzing channel 78: 0.9896907216494846
# Analyzing channel 79: 0.9896907216494846
# Analyzing channel 80: 0.9896907216494846
# Analyzing channel 81: 1.0
# Analyzing channel 82: 1.0
# Analyzing channel 83: 0.9484536082474226
# Analyzing channel 84: 0.9587628865979382
# Analyzing channel 85: 0.9175257731958762
# Analyzing channel 86: 1.0
# Analyzing channel 87: 0.9690721649484536
# Analyzing channel 88: 0.9278350515463918
# Analyzing channel 89: 0.9484536082474226
# Analyzing channel 90: 1.0
# Analyzing channel 91: 1.0
# Analyzing channel 92: 0.979381443298969
# Analyzing channel 93: 1.0
# Analyzing channel 94: 1.0
# Analyzing channel 95: 1.0
# Analyzing channel 96: 0.9896907216494846
# Analyzing channel 97: 1.0
# Analyzing channel 98: 1.0
# Analyzing channel 99: 1.0
# Analyzing channel 100: 0.9896907216494846
# Analyzing channel 101: 0.9896907216494846
# Analyzing channel 102: 0.9896907216494846
# Analyzing channel 103: 1.0
# Analyzing channel 104: 0.9896907216494846
# Analyzing channel 105: 0.9690721649484536
# Analyzing channel 106: 0.9896907216494846
# Analyzing channel 107: 0.9896907216494846
# Analyzing channel 108: 1.0
# Analyzing channel 109: 1.0
# Analyzing channel 110: 0.9896907216494846
# Analyzing channel 41: 0.9375
# Analyzing channel 42: 1.0
# Analyzing channel 43: 0.90625
# Analyzing channel 44: 0.9895833333333334
# Analyzing channel 45: 0.9791666666666666
# Analyzing channel 46: 0.90625
# Analyzing channel 47: 0.9375
# Analyzing channel 48: 0.9791666666666666
# Analyzing channel 49: 0.96875
# Analyzing channel 50: 0.9583333333333334
# Analyzing channel 51: 0.9375
# Analyzing channel 52: 0.96875
# Analyzing channel 53: 0.96875
# Analyzing channel 54: 0.90625
# Analyzing channel 55: 0.9791666666666666
# Analyzing channel 56: 0.9791666666666666
# Analyzing channel 57: 0.9895833333333334
# Analyzing channel 58: 0.9791666666666666
# Analyzing channel 59: 0.8229166666666666
# Analyzing channel 60: 0.8229166666666666
# Analyzing channel 61: 0.9791666666666666
# Analyzing channel 62: 0.5625
# Analyzing channel 63: 0.8020833333333334
# Analyzing channel 64: 0.84375
# Analyzing channel 65: 0.6979166666666666
# Analyzing channel 66: 0.8229166666666666
# Analyzing channel 67: 0.9583333333333334
# Analyzing channel 68: 1.0
# Analyzing channel 69: 0.8854166666666666
# Analyzing channel 70: 0.90625
# Analyzing channel 71: 0.9895833333333334
# Analyzing channel 72: 0.8333333333333334
# Analyzing channel 73: 0.8020833333333334
# Analyzing channel 74: 0.6041666666666666
# Analyzing channel 75: 0.9895833333333334
# Analyzing channel 76: 0.9479166666666666
# Analyzing channel 77: 0.8541666666666666
# Analyzing channel 78: 0.9583333333333334
# Analyzing channel 79: 0.9895833333333334
# Analyzing channel 80: 0.9791666666666666
# Analyzing channel 81: 0.9791666666666666
# Analyzing channel 82: 0.8645833333333334
# Analyzing channel 83: 0.9791666666666666
# Analyzing channel 84: 0.90625
# Analyzing channel 85: 0.9791666666666666
# Analyzing channel 86: 0.9791666666666666
# Analyzing channel 87: 0.9895833333333334
# Analyzing channel 88: 0.9791666666666666
# Analyzing channel 89: 0.9583333333333334
# Analyzing channel 90: 0.9895833333333334
# Analyzing channel 91: 0.8854166666666666
# Analyzing channel 92: 0.6770833333333334
# Analyzing channel 93: 0.6041666666666666
# Analyzing channel 94: 0.6145833333333334
# Analyzing channel 95: 0.9479166666666666
# Analyzing channel 96: 0.9895833333333334
# Analyzing channel 97: 0.9791666666666666
# Analyzing channel 98: 0.9791666666666666
# Analyzing channel 99: 0.9791666666666666
# Analyzing channel 100: 0.9895833333333334
# Analyzing channel 101: 0.9791666666666666
# Analyzing channel 102: 0.96875
# Analyzing channel 103: 0.9791666666666666
# Analyzing channel 104: 0.9375
# Analyzing channel 105: 0.9791666666666666
# Analyzing channel 106: 0.9791666666666666
# Analyzing channel 107: 0.9895833333333334
# Analyzing channel 108: 0.9791666666666666
# Analyzing channel 109: 0.9791666666666666
# Analyzing channel 110: 0.9791666666666666
# Analyzing channel 111: 0.6770833333333334
# Analyzing channel 112: 1.0
# Analyzing channel 113: 0.65625
# Analyzing channel 114: 0.8854166666666666
# Analyzing channel 115: 0.6041666666666666
# Analyzing channel 116: 1.0
# Analyzing channel 117: 0.5833333333333334
# Analyzing channel 118: 0.875
# Analyzing channel 119: 0.90625
# Analyzing channel 120: 0.9791666666666666
# Analyzing channel 121: 0.6875
# Analyzing channel 122: 0.9479166666666666
# Analyzing channel 123: 0.7083333333333334
# Analyzing channel 124: 0.4791666666666667
# Analyzing channel 125: 0.8333333333333334
# Analyzing channel 126: 0.5208333333333334
# Analyzing channel 127: 0.5208333333333334
# Analyzing channel 128: 0.5208333333333334
# Analyzing channel 129: 0.9791666666666666
# Analyzing channel 130: 1.0
# Analyzing channel 131: 0.9791666666666666
# Analyzing channel 132: 0.9583333333333334
# Analyzing channel 133: 0.8645833333333334
# Analyzing channel 134: 1.0
# Analyzing channel 135: 0.4895833333333333
# Analyzing channel 136: 0.9583333333333334
# Analyzing channel 137: 0.78125
# Analyzing channel 138: 0.6354166666666666
# Analyzing channel 139: 0.5833333333333334
# Analyzing channel 140: 0.4791666666666667
# Analyzing channel 141: 0.75
# Analyzing channel 142: 0.78125
# Analyzing channel 143: 0.5729166666666666
# Analyzing channel 144: 0.6354166666666666
# Analyzing channel 145: 0.4895833333333333
# Analyzing channel 146: 0.84375
# Analyzing channel 147: 0.7604166666666666
# Analyzing channel 148: 0.4895833333333333
# Analyzing channel 149: 0.4895833333333333
# Fold:6 , original accuracy: 1.0
# Analyzing channel 0: 0.8854166666666666
# Analyzing channel 1: 0.9895833333333334
# Analyzing channel 2: 0.90625
# Analyzing channel 3: 0.84375
# Analyzing channel 4: 0.9791666666666666
# Analyzing channel 5: 0.9583333333333334
# Analyzing channel 6: 0.875
# Analyzing channel 7: 0.6979166666666666
# Analyzing channel 8: 0.96875
# Analyzing channel 9: 0.9375
# Analyzing channel 10: 0.9895833333333334
# Analyzing channel 11: 0.9166666666666666
# Analyzing channel 12: 0.8229166666666666
# Analyzing channel 13: 0.9791666666666666
# Analyzing channel 14: 0.9791666666666666
# Analyzing channel 15: 1.0
# Analyzing channel 16: 1.0
# Analyzing channel 17: 1.0
# Analyzing channel 18: 1.0
# Analyzing channel 19: 1.0
# Analyzing channel 20: 0.90625
# Analyzing channel 21: 1.0
# Analyzing channel 22: 0.96875
# Analyzing channel 23: 0.9895833333333334
# Analyzing channel 24: 0.4791666666666667
# Analyzing channel 25: 0.8958333333333334
# Analyzing channel 26: 0.9583333333333334
# Analyzing channel 27: 0.8958333333333334
# Analyzing channel 28: 0.875
# Analyzing channel 29: 0.4791666666666667
# Analyzing channel 30: 0.96875
# Analyzing channel 31: 0.9166666666666666
# Analyzing channel 32: 0.9791666666666666
# Analyzing channel 33: 0.9895833333333334
# Analyzing channel 34: 1.0
# Analyzing channel 35: 0.9791666666666666
# Analyzing channel 36: 1.0
# Analyzing channel 37: 0.90625
# Analyzing channel 38: 0.9375
# Analyzing channel 39: 0.9791666666666666
# Analyzing channel 40: 0.9583333333333334
# Analyzing channel 41: 0.9895833333333334
# Analyzing channel 42: 0.9791666666666666
# Analyzing channel 43: 0.9895833333333334
# Analyzing channel 44: 0.90625
# Analyzing channel 45: 0.9895833333333334
# Analyzing channel 130: 1.0
# Analyzing channel 131: 0.9895833333333334
# Analyzing channel 132: 0.9270833333333334
# Analyzing channel 133: 1.0
# Analyzing channel 134: 0.9583333333333334
# Analyzing channel 135: 0.9895833333333334
# Analyzing channel 136: 0.9375
# Analyzing channel 137: 0.7916666666666666
# Analyzing channel 138: 0.59375
# Analyzing channel 139: 0.4791666666666667
# Analyzing channel 140: 0.4583333333333333
# Analyzing channel 141: 0.7708333333333334
# Analyzing channel 142: 0.8541666666666666
# Analyzing channel 143: 0.84375
# Analyzing channel 144: 0.59375
# Analyzing channel 145: 0.7916666666666666
# Analyzing channel 146: 0.5833333333333334
# Analyzing channel 147: 0.875
# Analyzing channel 148: 0.4791666666666667
# Analyzing channel 149: 0.4791666666666667
# Fold:7 , original accuracy: 1.0
# Analyzing channel 0: 0.75
# Analyzing channel 1: 0.9583333333333334
# Analyzing channel 2: 0.9479166666666666
# Analyzing channel 3: 0.9895833333333334
# Analyzing channel 4: 1.0
# Analyzing channel 5: 0.9583333333333334
# Analyzing channel 6: 0.9583333333333334
# Analyzing channel 7: 0.8020833333333334
# Analyzing channel 8: 1.0
# Analyzing channel 9: 0.9791666666666666
# Analyzing channel 10: 1.0
# Analyzing channel 11: 0.9583333333333334
# Analyzing channel 12: 0.9895833333333334
# Analyzing channel 13: 1.0
# Analyzing channel 14: 0.9791666666666666
# Analyzing channel 15: 0.9479166666666666
# Analyzing channel 16: 1.0
# Analyzing channel 17: 0.9583333333333334
# Analyzing channel 18: 0.8958333333333334
# Analyzing channel 19: 0.9895833333333334
# Analyzing channel 20: 0.9895833333333334
# Analyzing channel 21: 0.9895833333333334
# Analyzing channel 22: 0.9895833333333334
# Analyzing channel 23: 0.9583333333333334
# Analyzing channel 24: 0.78125
# Analyzing channel 25: 0.6666666666666666
# Analyzing channel 26: 0.9895833333333334
# Analyzing channel 27: 0.9479166666666666
# Analyzing channel 28: 0.9583333333333334
# Analyzing channel 29: 0.96875
# Analyzing channel 30: 1.0
# Analyzing channel 31: 1.0
# Analyzing channel 32: 1.0
# Analyzing channel 33: 1.0
# Analyzing channel 34: 1.0
# Analyzing channel 35: 0.9791666666666666
# Analyzing channel 36: 0.9791666666666666
# Analyzing channel 37: 1.0
# Analyzing channel 38: 1.0
# Analyzing channel 39: 0.9791666666666666
# Analyzing channel 40: 1.0
# Analyzing channel 41: 0.9375
# Analyzing channel 42: 0.9479166666666666
# Analyzing channel 43: 0.7604166666666666
# Analyzing channel 44: 1.0
# Analyzing channel 45: 0.9479166666666666
# Analyzing channel 46: 0.9895833333333334
# Analyzing channel 47: 1.0
# Analyzing channel 48: 0.9375
# Analyzing channel 49: 0.96875
# Analyzing channel 50: 0.9895833333333334
# Analyzing channel 51: 0.9583333333333334
# Analyzing channel 52: 0.9166666666666666
# Analyzing channel 53: 0.71875
# Analyzing channel 54: 0.9583333333333334
# Analyzing channel 55: 0.9791666666666666
# Analyzing channel 56: 0.9895833333333334
# Analyzing channel 57: 1.0
# Analyzing channel 58: 0.9791666666666666
# Analyzing channel 59: 0.96875
# Analyzing channel 60: 0.9895833333333334
# Analyzing channel 61: 0.8645833333333334
# Analyzing channel 62: 0.90625
# Analyzing channel 63: 0.875
# Analyzing channel 64: 0.9895833333333334
# Analyzing channel 65: 0.875
# Analyzing channel 66: 0.9895833333333334
# Analyzing channel 67: 0.9270833333333334
# Analyzing channel 68: 0.9791666666666666
# Analyzing channel 69: 1.0
# Analyzing channel 70: 0.9895833333333334
# Analyzing channel 71: 0.96875
# Analyzing channel 72: 0.9583333333333334
# Analyzing channel 73: 0.8958333333333334
# Analyzing channel 74: 0.78125
# Analyzing channel 75: 0.8541666666666666
# Analyzing channel 76: 0.9479166666666666
# Analyzing channel 77: 0.8958333333333334
# Analyzing channel 78: 0.9270833333333334
# Analyzing channel 79: 0.96875
# Analyzing channel 80: 0.9895833333333334
# Analyzing channel 81: 0.9895833333333334
# Analyzing channel 82: 0.9895833333333334
# Analyzing channel 83: 1.0
# Analyzing channel 84: 1.0
# Analyzing channel 85: 0.9895833333333334
# Analyzing channel 86: 0.9895833333333334
# Analyzing channel 87: 0.9583333333333334
# Analyzing channel 88: 0.9479166666666666
# Analyzing channel 89: 0.875
# Analyzing channel 90: 0.8333333333333334
# Analyzing channel 91: 0.8125
# Analyzing channel 92: 0.9583333333333334
# Analyzing channel 93: 0.9583333333333334
# Analyzing channel 94: 1.0
# Analyzing channel 95: 1.0
# Analyzing channel 96: 0.9791666666666666
# Analyzing channel 97: 0.9895833333333334
# Analyzing channel 98: 1.0
# Analyzing channel 99: 1.0
# Analyzing channel 100: 0.9895833333333334
# Analyzing channel 101: 0.9791666666666666
# Analyzing channel 102: 0.9895833333333334
# Analyzing channel 103: 1.0
# Analyzing channel 104: 1.0
# Analyzing channel 105: 0.8854166666666666
# Analyzing channel 106: 0.9166666666666666
# Analyzing channel 107: 0.7291666666666666
# Analyzing channel 108: 0.96875
# Analyzing channel 109: 0.96875
# Analyzing channel 110: 0.9895833333333334
# Analyzing channel 111: 1.0
# Analyzing channel 112: 1.0
# Analyzing channel 113: 0.9895833333333334
# Analyzing channel 114: 0.9895833333333334
# Analyzing channel 115: 0.9791666666666666
# Analyzing channel 116: 0.9895833333333334
# Analyzing channel 117: 0.9791666666666666
# Analyzing channel 118: 1.0
# Analyzing channel 119: 1.0
# Analyzing channel 120: 1.0
# Analyzing channel 121: 0.9895833333333334
# Analyzing channel 122: 0.9895833333333334
# Analyzing channel 123: 1.0
# Analyzing channel 124: 1.0
# Analyzing channel 125: 1.0
# Analyzing channel 126: 1.0
# Analyzing channel 127: 1.0
# Analyzing channel 128: 1.0
# Analyzing channel 129: 1.0
# Analyzing channel 130: 0.5
# Analyzing channel 131: 0.8229166666666666
# Analyzing channel 132: 0.7604166666666666
# Analyzing channel 133: 0.96875
# Analyzing channel 134: 0.5520833333333334
# Analyzing channel 135: 0.9791666666666666
# Analyzing channel 136: 0.9895833333333334
# Analyzing channel 137: 0.96875
# Analyzing channel 138: 1.0
# Analyzing channel 139: 1.0
# Analyzing channel 140: 0.6770833333333334
# Analyzing channel 141: 0.8854166666666666
# Analyzing channel 142: 0.8020833333333334
# Analyzing channel 143: 0.9895833333333334
# Analyzing channel 144: 0.5
# Analyzing channel 145: 0.8541666666666666
# Analyzing channel 146: 0.8125
# Analyzing channel 147: 0.78125
# Analyzing channel 148: 0.5
# Analyzing channel 149: 0.5208333333333334
# Fold:8 , original accuracy: 1.0
# Analyzing channel 0: 0.6979166666666666
# Analyzing channel 1: 1.0
# Analyzing channel 2: 1.0
# Analyzing channel 3: 0.875
# Analyzing channel 4: 0.90625
# Analyzing channel 5: 0.9791666666666666
# Analyzing channel 6: 0.6145833333333334
# Analyzing channel 7: 0.6770833333333334
# Analyzing channel 8: 0.7083333333333334
# Analyzing channel 9: 0.5520833333333334
# Analyzing channel 10: 0.7708333333333334
# Analyzing channel 11: 0.625
# Analyzing channel 12: 0.8020833333333334
# Analyzing channel 13: 0.6875
# Analyzing channel 14: 0.59375
# Analyzing channel 15: 0.53125
# Analyzing channel 16: 0.5104166666666666
# Analyzing channel 17: 0.5416666666666666
# Analyzing channel 18: 0.5
# Analyzing channel 19: 0.6145833333333334
# Analyzing channel 20: 0.78125
# Analyzing channel 21: 0.65625
# Analyzing channel 22: 0.4791666666666667
# Analyzing channel 23: 0.4791666666666667
# Analyzing channel 24: 0.4895833333333333
# Analyzing channel 25: 0.5833333333333334
# Analyzing channel 26: 0.9791666666666666
# Analyzing channel 27: 0.4791666666666667
# Analyzing channel 28: 1.0
# Analyzing channel 29: 1.0
# Analyzing channel 30: 0.7916666666666666
# Analyzing channel 31: 0.9166666666666666
# Analyzing channel 32: 0.9375
# Analyzing channel 33: 0.5
# Analyzing channel 34: 0.7916666666666666
# Analyzing channel 35: 0.6979166666666666
# Analyzing channel 36: 0.5416666666666666
# Analyzing channel 37: 0.78125
# Analyzing channel 38: 0.5625
# Analyzing channel 39: 0.4791666666666667
# Analyzing channel 40: 0.9583333333333334
# Analyzing channel 41: 0.4791666666666667
# Analyzing channel 42: 0.6145833333333334
# Analyzing channel 43: 0.7708333333333334
# Analyzing channel 44: 0.75
# Analyzing channel 45: 0.8958333333333334
# Analyzing channel 46: 0.4791666666666667
# Analyzing channel 47: 1.0
# Analyzing channel 48: 0.9479166666666666
# Analyzing channel 49: 0.5729166666666666
# Analyzing channel 50: 0.7916666666666666
# Analyzing channel 51: 0.9479166666666666
# Analyzing channel 52: 0.625
# Analyzing channel 53: 0.8020833333333334
# Analyzing channel 54: 0.5208333333333334
# Analyzing channel 55: 0.625
# Analyzing channel 56: 0.78125
# Analyzing channel 57: 0.4791666666666667
# Analyzing channel 58: 0.4791666666666667
# Analyzing channel 59: 0.5104166666666666
# Analyzing channel 60: 0.9479166666666666
# Analyzing channel 61: 0.6666666666666666
# Analyzing channel 62: 0.7083333333333334
# Analyzing channel 63: 0.8125
# Analyzing channel 64: 0.6354166666666666
# Analyzing channel 65: 0.4791666666666667
# Analyzing channel 66: 0.4791666666666667
# Analyzing channel 67: 0.4791666666666667
# Analyzing channel 147: 0.4791666666666667
# Analyzing channel 148: 0.5
# Analyzing channel 149: 0.4791666666666667
# Fold:9 , original accuracy: 1.0
# Analyzing channel 0: 0.9166666666666666
# Analyzing channel 1: 1.0
# Analyzing channel 2: 0.9895833333333334
# Analyzing channel 3: 0.9895833333333334
# Analyzing channel 4: 1.0
# Analyzing channel 5: 1.0
# Analyzing channel 6: 0.84375
# Analyzing channel 7: 0.9583333333333334
# Analyzing channel 8: 0.75
# Analyzing channel 9: 0.90625
# Analyzing channel 10: 0.9791666666666666
# Analyzing channel 11: 0.9583333333333334
# Analyzing channel 12: 0.9479166666666666
# Analyzing channel 13: 1.0
# Analyzing channel 14: 1.0
# Analyzing channel 15: 0.8125
# Analyzing channel 16: 0.9479166666666666
# Analyzing channel 17: 0.6354166666666666
# Analyzing channel 18: 0.9375
# Analyzing channel 19: 0.9270833333333334
# Analyzing channel 20: 0.9791666666666666
# Analyzing channel 21: 0.71875
# Analyzing channel 22: 0.96875
# Analyzing channel 23: 0.4791666666666667
# Analyzing channel 24: 0.4791666666666667
# Analyzing channel 25: 0.9791666666666666
# Analyzing channel 26: 0.9791666666666666
# Analyzing channel 27: 0.7291666666666666
# Analyzing channel 28: 0.9583333333333334
# Analyzing channel 29: 0.96875
# Analyzing channel 30: 0.9791666666666666
# Analyzing channel 31: 1.0
# Analyzing channel 32: 1.0
# Analyzing channel 33: 1.0
# Analyzing channel 34: 0.9375
# Analyzing channel 35: 1.0
# Analyzing channel 36: 0.7604166666666666
# Analyzing channel 37: 0.7395833333333334
# Analyzing channel 38: 0.9895833333333334
# Analyzing channel 39: 0.7916666666666666
# Analyzing channel 40: 0.9166666666666666
# Analyzing channel 41: 0.6041666666666666
# Analyzing channel 42: 0.59375
# Analyzing channel 43: 0.7916666666666666
# Analyzing channel 44: 0.9895833333333334
# Analyzing channel 45: 0.9895833333333334
# Analyzing channel 46: 1.0
# Analyzing channel 47: 0.8958333333333334
# Analyzing channel 48: 0.9583333333333334
# Analyzing channel 49: 1.0
# Analyzing channel 50: 1.0
# Analyzing channel 51: 0.96875
# Analyzing channel 52: 1.0
# Analyzing channel 53: 0.7916666666666666
# Analyzing channel 54: 0.96875
# Analyzing channel 55: 0.9791666666666666
# Analyzing channel 56: 0.9270833333333334
# Analyzing channel 57: 0.4791666666666667
# Analyzing channel 58: 0.5833333333333334
# Analyzing channel 59: 0.5833333333333334
# Analyzing channel 60: 0.9895833333333334
# Analyzing channel 61: 0.75
# Analyzing channel 62: 0.625
# Analyzing channel 63: 0.5208333333333334
# Analyzing channel 64: 0.8645833333333334
# Analyzing channel 65: 0.5833333333333334
# Analyzing channel 66: 0.4791666666666667
# Analyzing channel 67: 0.5104166666666666
# Analyzing channel 68: 0.6458333333333334
# Analyzing channel 69: 0.6458333333333334
# Analyzing channel 70: 0.625
# Analyzing channel 71: 0.9479166666666666
# Analyzing channel 72: 0.59375
# Analyzing channel 73: 0.5833333333333334
# Analyzing channel 74: 0.8020833333333334
# Analyzing channel 75: 1.0
# Analyzing channel 76: 0.9791666666666666
# Analyzing channel 77: 0.9375
# Analyzing channel 78: 1.0
# Analyzing channel 79: 1.0
# Analyzing channel 80: 0.9791666666666666
# Analyzing channel 81: 0.9895833333333334
# Analyzing channel 82: 1.0
# Analyzing channel 83: 1.0
# Analyzing channel 84: 0.9375
# Analyzing channel 85: 0.9895833333333334
# Analyzing channel 86: 0.9479166666666666
# Analyzing channel 87: 0.96875
# Analyzing channel 88: 1.0
# Analyzing channel 89: 1.0
# Analyzing channel 90: 1.0
# Analyzing channel 91: 1.0
# Analyzing channel 92: 1.0
# Analyzing channel 93: 1.0
# Analyzing channel 94: 1.0
# Analyzing channel 95: 1.0
# Analyzing channel 96: 0.9895833333333334
# Analyzing channel 97: 1.0
# Analyzing channel 98: 0.9791666666666666
# Analyzing channel 99: 0.9895833333333334
# Analyzing channel 100: 0.9895833333333334
# Analyzing channel 101: 1.0
# Analyzing channel 102: 1.0
# Analyzing channel 103: 1.0
# Analyzing channel 104: 1.0
# Analyzing channel 105: 1.0
# Analyzing channel 106: 1.0
# Analyzing channel 107: 1.0
# Analyzing channel 108: 1.0
# Analyzing channel 109: 1.0
# Analyzing channel 110: 1.0
# Analyzing channel 111: 0.9166666666666666
# Analyzing channel 112: 1.0
# Analyzing channel 113: 1.0
# Analyzing channel 114: 0.9375
# Analyzing channel 115: 0.7604166666666666
# Analyzing channel 116: 0.9479166666666666
# Analyzing channel 117: 0.78125
# Analyzing channel 118: 0.5
# Analyzing channel 119: 0.84375
# Analyzing channel 120: 0.5208333333333334
# Analyzing channel 121: 0.7083333333333334
# Analyzing channel 122: 0.8958333333333334
# Analyzing channel 123: 0.5520833333333334
# Analyzing channel 124: 0.6041666666666666
# Analyzing channel 125: 0.8020833333333334
# Analyzing channel 126: 0.9375
# Analyzing channel 127: 1.0
# Analyzing channel 128: 0.9895833333333334
# Analyzing channel 129: 0.875
# Analyzing channel 130: 0.9791666666666666
# Analyzing channel 131: 0.5208333333333334
# Analyzing channel 132: 0.7083333333333334
# Analyzing channel 133: 0.8333333333333334
# Analyzing channel 134: 0.5729166666666666
# Analyzing channel 135: 0.8020833333333334
# Analyzing channel 136: 0.5208333333333334
# Analyzing channel 137: 0.53125
# Analyzing channel 138: 0.5208333333333334
# Analyzing channel 139: 0.4791666666666667
# Analyzing channel 140: 0.4791666666666667
# Analyzing channel 141: 0.4895833333333333
# Analyzing channel 142: 0.6458333333333334
# Analyzing channel 143: 0.5208333333333334
# Analyzing channel 144: 0.6458333333333334
# Analyzing channel 145: 0.7083333333333334
# Analyzing channel 146: 0.71875
# Analyzing channel 147: 0.7395833333333334
# Analyzing channel 148: 0.4791666666666667
# Analyzing channel 149: 0.5104166666666666
# Fold:10 , original accuracy: 1.0
# Analyzing channel 0: 0.75
# Analyzing channel 1: 1.0
# Analyzing channel 2: 0.9895833333333334
# Analyzing channel 3: 0.8541666666666666
# Analyzing channel 4: 0.9895833333333334
# Analyzing channel 5: 0.9791666666666666
# Analyzing channel 6: 0.8541666666666666
# Analyzing channel 7: 0.9791666666666666
# Analyzing channel 8: 1.0
# Analyzing channel 9: 0.75
# Analyzing channel 10: 0.96875
# Analyzing channel 11: 0.7604166666666666
# Analyzing channel 12: 0.6145833333333334
# Analyzing channel 13: 0.9479166666666666
# Analyzing channel 14: 0.9270833333333334
# Analyzing channel 15: 0.9583333333333334
# Analyzing channel 16: 0.5625
# Analyzing channel 17: 0.5416666666666666
# Analyzing channel 18: 0.7916666666666666
# Analyzing channel 19: 0.9583333333333334
# Analyzing channel 20: 0.4791666666666667
# Analyzing channel 21: 0.8541666666666666
# Analyzing channel 22: 0.78125
# Analyzing channel 23: 1.0
# Analyzing channel 24: 0.8854166666666666
# Analyzing channel 25: 0.8854166666666666
# Analyzing channel 26: 0.78125
# Analyzing channel 27: 0.9375
# Analyzing channel 28: 0.6041666666666666
# Analyzing channel 29: 0.71875
# Analyzing channel 30: 0.9166666666666666
# Analyzing channel 31: 0.9479166666666666
# Analyzing channel 32: 1.0
# Analyzing channel 33: 1.0
# Analyzing channel 34: 1.0
# Analyzing channel 35: 0.9895833333333334
# Analyzing channel 36: 0.9166666666666666
# Analyzing channel 37: 0.9166666666666666
# Analyzing channel 38: 0.8229166666666666
# Analyzing channel 39: 0.71875
# Analyzing channel 40: 0.96875
# Analyzing channel 41: 0.8541666666666666
# Analyzing channel 42: 0.8958333333333334
# Analyzing channel 43: 0.7395833333333334
# Analyzing channel 44: 0.9375
# Analyzing channel 45: 1.0
# Analyzing channel 46: 0.8229166666666666
# Analyzing channel 47: 0.9791666666666666
# Analyzing channel 48: 0.7604166666666666
# Analyzing channel 49: 0.9895833333333334
# Analyzing channel 50: 0.9895833333333334
# Analyzing channel 51: 0.7291666666666666
# Analyzing channel 52: 0.6041666666666666
# Analyzing channel 53: 1.0
# Analyzing channel 54: 0.65625
# Analyzing channel 55: 0.9583333333333334
# Analyzing channel 56: 0.9791666666666666
# Analyzing channel 57: 0.4791666666666667
# Analyzing channel 58: 0.5833333333333334
# Analyzing channel 59: 0.90625
# Analyzing channel 60: 0.5520833333333334
# Analyzing channel 61: 0.84375
# Analyzing channel 62: 0.75
# Analyzing channel 63: 0.5208333333333334
# Analyzing channel 64: 0.6666666666666666
# Analyzing channel 65: 0.8020833333333334
# Analyzing channel 66: 0.4791666666666667
# Analyzing channel 67: 0.4791666666666667
# Analyzing channel 68: 0.9479166666666666
# Analyzing channel 69: 0.8541666666666666
# Analyzing channel 70: 0.5208333333333334
# Analyzing channel 71: 0.9375
# Analyzing channel 72: 0.6354166666666666
# Analyzing channel 73: 0.4791666666666667
# Analyzing channel 74: 0.6041666666666666
# Analyzing channel 75: 0.9895833333333334
# Analyzing channel 76: 0.8645833333333334
# Analyzing channel 77: 1.0
# Analyzing channel 78: 1.0
# Analyzing channel 79: 1.0
# Analyzing channel 80: 1.0
# Analyzing channel 81: 1.0
# Analyzing channel 82: 1.0
# Analyzing channel 83: 0.8125
# Analyzing channel 84: 0.9895833333333334
# Analyzing channel 85: 0.8958333333333334
# Analyzing channel 86: 0.65625
# Analyzing channel 87: 0.9895833333333334
# Analyzing channel 88: 1.0
# Analyzing channel 89: 0.78125
# Analyzing channel 90: 0.9791666666666666
# Analyzing channel 91: 1.0
# Analyzing channel 92: 0.90625
# Analyzing channel 93: 1.0
# Analyzing channel 94: 1.0
# Analyzing channel 95: 1.0
# Analyzing channel 96: 1.0
# Analyzing channel 97: 0.9791666666666666
# Analyzing channel 98: 1.0
# Analyzing channel 99: 0.875
# Analyzing channel 100: 0.78125
# Analyzing channel 101: 0.9791666666666666
# Analyzing channel 102: 0.8020833333333334
# Analyzing channel 103: 0.9479166666666666
# Analyzing channel 104: 1.0
# Analyzing channel 105: 0.8958333333333334
# Analyzing channel 106: 0.8958333333333334
# Analyzing channel 107: 1.0
# Analyzing channel 108: 0.9791666666666666
# Analyzing channel 109: 0.65625
# Analyzing channel 110: 0.9791666666666666
# Analyzing channel 111: 0.9270833333333334
# Analyzing channel 112: 0.6145833333333334
# Analyzing channel 113: 0.9479166666666666
# Analyzing channel 114: 0.4791666666666667
# Analyzing channel 115: 0.6041666666666666
# Analyzing channel 116: 0.5625
# Analyzing channel 117: 0.5208333333333334
# Analyzing channel 118: 0.8125
# Analyzing channel 119: 0.9166666666666666
# Analyzing channel 120: 0.4791666666666667
# Analyzing channel 121: 0.53125
# Analyzing channel 122: 0.5208333333333334
# Analyzing channel 123: 0.5208333333333334
# Analyzing channel 124: 0.78125
# Analyzing channel 125: 0.96875
# Analyzing channel 126: 0.53125
# Analyzing channel 127: 1.0
# Analyzing channel 128: 0.875
# Analyzing channel 129: 0.7395833333333334
# Analyzing channel 130: 0.9375
# Analyzing channel 131: 0.5208333333333334
# Analyzing channel 132: 0.5208333333333334
# Analyzing channel 133: 0.4791666666666667
# Analyzing channel 134: 0.4791666666666667
# Analyzing channel 135: 0.5208333333333334
# Analyzing channel 136: 0.5208333333333334
# Analyzing channel 137: 0.5208333333333334
# Analyzing channel 138: 0.4791666666666667
# Analyzing channel 139: 0.4791666666666667
# Analyzing channel 140: 0.4791666666666667
# Analyzing channel 141: 0.5
# Analyzing channel 142: 0.5208333333333334
# Analyzing channel 143: 0.5208333333333334
# Analyzing channel 144: 0.5208333333333334
# Analyzing channel 145: 0.4791666666666667
# Analyzing channel 146: 0.5208333333333334
# Analyzing channel 147: 0.5
# Analyzing channel 148: 0.4895833333333333
# Analyzing channel 149: 0.4791666666666667

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

means = np.mean(SA, axis=0)
stds = np.std(SA, axis=0)

fig, ax = plt.subplots()
clrs = sns.color_palette()
with sns.axes_style("darkgrid"):
    epochs = list(range(150))
    
    ax.plot(epochs, means, c=clrs[0])
    ax.fill_between(epochs, means-stds, means+stds ,alpha=0.3, facecolor=clrs[0])
    ax.legend()
    ax.set_yscale('log')

plt.savefig('Bands_importance_plot_Avocado_hyper3dnet_crossvalidation.png', dpi=1200)
# Out:
# No handles with labels found to put in legend.

# %%
list_importance = list(zip(means, range(0, 150)))
sortedlist = sorted(list_importance, key = lambda x: x[0], reverse=True)
print('\n\nPrinting saliency and spectral band')
for x in sortedlist: 
    print("Spectral band: " + str(x[1]) + "\tSaliency: " + str(x[0])) 

import matplotlib.pyplot as plt
plt.plot(means)
plt.savefig('Bands_importance_MEANS_plot_Avocado_hyper3dnet_crossvalidation.png', dpi=1200)
# Out:
# Printing saliency and spectral band
# Spectral band: 149	Saliency: 31.294689559936522
# Spectral band: 148	Saliency: 31.18961410522461
# Spectral band: 140	Saliency: 26.188066482543945
# Spectral band: 143	Saliency: 24.53762106895447
# Spectral band: 139	Saliency: 24.39190101623535
# Spectral band: 145	Saliency: 24.010954761505126
# Spectral band: 138	Saliency: 21.950075960159303
# Spectral band: 142	Saliency: 21.49444341659546
# Spectral band: 24	Saliency: 21.14882411956787
# Spectral band: 147	Saliency: 20.762753677368163
# Spectral band: 144	Saliency: 20.658764457702638
# Spectral band: 73	Saliency: 20.631139278411865
# Spectral band: 146	Saliency: 20.05632448196411
# Spectral band: 141	Saliency: 19.846172952651976
# Spectral band: 74	Saliency: 18.90817708969116
# Spectral band: 131	Saliency: 18.287974548339843
# Spectral band: 66	Saliency: 18.163862466812134
# Spectral band: 123	Saliency: 17.942363739013672
# Spectral band: 137	Saliency: 17.609372043609618
# Spectral band: 136	Saliency: 16.751197814941406
# Spectral band: 67	Saliency: 16.510656213760377
# Spectral band: 70	Saliency: 15.560031127929687
# Spectral band: 57	Saliency: 15.16754961013794
# Spectral band: 126	Saliency: 14.829623222351074
# Spectral band: 135	Saliency: 14.657360649108886
# Spectral band: 134	Saliency: 14.501569366455078
# Spectral band: 124	Saliency: 14.438427734375
# Spectral band: 115	Saliency: 14.377651166915893
# Spectral band: 72	Saliency: 14.289049434661866
# Spectral band: 23	Saliency: 13.68275785446167
# Spectral band: 58	Saliency: 13.439655017852782
# Spectral band: 117	Saliency: 12.877667999267578
# Spectral band: 69	Saliency: 12.834647130966186
# Spectral band: 133	Saliency: 12.813043785095214
# Spectral band: 65	Saliency: 12.464857292175292
# Spectral band: 132	Saliency: 12.324456167221069
# Spectral band: 43	Saliency: 12.118152475357055
# Spectral band: 122	Saliency: 11.996600437164307
# Spectral band: 118	Saliency: 11.691632080078126
# Spectral band: 125	Saliency: 11.538405513763427
# Spectral band: 63	Saliency: 11.495194149017333
# Spectral band: 42	Saliency: 11.328251457214355
# Spectral band: 62	Saliency: 10.61284589767456
# Spectral band: 114	Saliency: 10.592717933654786
# Spectral band: 20	Saliency: 10.207929468154907
# Spectral band: 121	Saliency: 10.145871591567992
# Spectral band: 27	Saliency: 9.944500064849853
# Spectral band: 116	Saliency: 9.893983602523804
# Spectral band: 0	Saliency: 9.75466799736023
# Spectral band: 52	Saliency: 9.718063974380494
# Spectral band: 25	Saliency: 9.712931680679322
# Spectral band: 39	Saliency: 9.679981422424316
# Spectral band: 53	Saliency: 9.197807168960571
# Spectral band: 129	Saliency: 9.004129362106323
# Spectral band: 64	Saliency: 8.978681612014771
# Spectral band: 51	Saliency: 8.905469608306884
# Spectral band: 17	Saliency: 8.838088274002075
# Spectral band: 22	Saliency: 8.597741508483887
# Spectral band: 61	Saliency: 8.507856702804565
# Spectral band: 21	Saliency: 8.449647188186646
# Spectral band: 59	Saliency: 8.260904598236085
# Spectral band: 41	Saliency: 7.88746337890625
# Spectral band: 130	Saliency: 7.88637056350708
# Spectral band: 68	Saliency: 7.45215630531311
# Spectral band: 55	Saliency: 7.3661217212677
# Spectral band: 11	Saliency: 7.278609895706177
# Spectral band: 6	Saliency: 7.126668977737427
# Spectral band: 93	Saliency: 7.085126686096191
# Spectral band: 127	Saliency: 6.983703565597534
# Spectral band: 37	Saliency: 6.8103502750396725
# Spectral band: 128	Saliency: 6.720466756820679
# Spectral band: 9	Saliency: 6.684951400756836
# Spectral band: 36	Saliency: 6.596350955963135
# Spectral band: 60	Saliency: 6.4660162925720215
# Spectral band: 16	Saliency: 6.277275276184082
# Spectral band: 28	Saliency: 6.1355915546417235
# Spectral band: 120	Saliency: 6.084880304336548
# Spectral band: 14	Saliency: 6.036925840377807
# Spectral band: 7	Saliency: 5.994995164871216
# Spectral band: 18	Saliency: 5.921591472625733
# Spectral band: 54	Saliency: 5.906397867202759
# Spectral band: 12	Saliency: 5.655790853500366
# Spectral band: 75	Saliency: 5.4355696678161625
# Spectral band: 112	Saliency: 5.429162836074829
# Spectral band: 77	Saliency: 5.417812442779541
# Spectral band: 29	Saliency: 5.4152483463287355
# Spectral band: 15	Saliency: 5.296262216567993
# Spectral band: 46	Saliency: 5.282350301742554
# Spectral band: 71	Saliency: 5.2369616508483885
# Spectral band: 49	Saliency: 5.229267644882202
# Spectral band: 19	Saliency: 4.940579795837403
# Spectral band: 105	Saliency: 4.926667022705078
# Spectral band: 89	Saliency: 4.905253934860229
# Spectral band: 38	Saliency: 4.836785316467285
# Spectral band: 111	Saliency: 4.6266326904296875
# Spectral band: 113	Saliency: 4.61143856048584
# Spectral band: 56	Saliency: 4.547005987167358
# Spectral band: 92	Saliency: 4.497577476501465
# Spectral band: 119	Saliency: 4.10015902519226
# Spectral band: 76	Saliency: 3.9886711120605467
# Spectral band: 8	Saliency: 3.7190261363983153
# Spectral band: 48	Saliency: 3.6798548221588137
# Spectral band: 86	Saliency: 3.664660596847534
# Spectral band: 33	Saliency: 3.662096118927002
# Spectral band: 78	Saliency: 3.6443350315093994
# Spectral band: 3	Saliency: 3.5861249923706056
# Spectral band: 90	Saliency: 3.5495184421539308
# Spectral band: 50	Saliency: 3.5039363861083985
# Spectral band: 94	Saliency: 3.201337289810181
# Spectral band: 34	Saliency: 3.173512887954712
# Spectral band: 84	Saliency: 3.1608837604522706
# Spectral band: 109	Saliency: 3.140560579299927
# Spectral band: 83	Saliency: 3.03804874420166
# Spectral band: 91	Saliency: 2.9798357009887697
# Spectral band: 44	Saliency: 2.9620779514312745
# Spectral band: 80	Saliency: 2.9304067611694338
# Spectral band: 45	Saliency: 2.8786057949066164
# Spectral band: 108	Saliency: 2.872196006774902
# Spectral band: 35	Saliency: 2.7696839809417724
# Spectral band: 88	Saliency: 2.7317948818206785
# Spectral band: 13	Saliency: 2.6190250873565675
# Spectral band: 31	Saliency: 2.593766117095947
# Spectral band: 40	Saliency: 2.5329894542694094
# Spectral band: 47	Saliency: 2.370982360839844
# Spectral band: 26	Saliency: 2.367136812210083
# Spectral band: 85	Saliency: 2.267188549041748
# Spectral band: 10	Saliency: 2.263342046737671
# Spectral band: 30	Saliency: 2.0974895477294924
# Spectral band: 79	Saliency: 2.097488355636597
# Spectral band: 82	Saliency: 1.8468833923339845
# Spectral band: 107	Saliency: 1.8000164031982422
# Spectral band: 102	Saliency: 1.6519245147705077
# Spectral band: 32	Saliency: 1.581083059310913
# Spectral band: 100	Saliency: 1.5772363185882567
# Spectral band: 2	Saliency: 1.5177413940429687
# Spectral band: 96	Saliency: 1.3696473121643067
# Spectral band: 106	Saliency: 1.3392588138580321
# Spectral band: 98	Saliency: 1.3240651130676269
# Spectral band: 87	Saliency: 1.2658528804779052
# Spectral band: 4	Saliency: 1.2063591480255127
# Spectral band: 81	Saliency: 1.0443526744842528
# Spectral band: 5	Saliency: 0.9228001117706299
# Spectral band: 101	Saliency: 0.8936944484710694
# Spectral band: 99	Saliency: 0.7734241008758544
# Spectral band: 1	Saliency: 0.7595118999481201
# Spectral band: 103	Saliency: 0.6709122657775879
# Spectral band: 95	Saliency: 0.56583571434021
# Spectral band: 104	Saliency: 0.3873530387878418
# Spectral band: 97	Saliency: 0.3126647472381592
# Spectral band: 110	Saliency: 0.2531705856323242

# %%
list_importance = list(zip(means, range(0, 150)))
sortedlist = sorted(list_importance, key = lambda x: x[0], reverse=True)
print('\n\nPrinting saliency and spectral band')
for x in sortedlist: 
    print("Spectral band: " + str(x[1]) + "\tSaliency: " + str(x[0])) 

import matplotlib.pyplot as plt
plt.plot(means)
plt.savefig('Bands_importance_MEANS_plot_Avocado_hyper3dnet_crossvalidation.png', dpi=1200)
# Out:
# Printing saliency and spectral band
# Spectral band: 149	Saliency: 31.294689559936522
# Spectral band: 148	Saliency: 31.18961410522461
# Spectral band: 140	Saliency: 26.188066482543945
# Spectral band: 143	Saliency: 24.53762106895447
# Spectral band: 139	Saliency: 24.39190101623535
# Spectral band: 145	Saliency: 24.010954761505126
# Spectral band: 138	Saliency: 21.950075960159303
# Spectral band: 142	Saliency: 21.49444341659546
# Spectral band: 24	Saliency: 21.14882411956787
# Spectral band: 147	Saliency: 20.762753677368163
# Spectral band: 144	Saliency: 20.658764457702638
# Spectral band: 73	Saliency: 20.631139278411865
# Spectral band: 146	Saliency: 20.05632448196411
# Spectral band: 141	Saliency: 19.846172952651976
# Spectral band: 74	Saliency: 18.90817708969116
# Spectral band: 131	Saliency: 18.287974548339843
# Spectral band: 66	Saliency: 18.163862466812134
# Spectral band: 123	Saliency: 17.942363739013672
# Spectral band: 137	Saliency: 17.609372043609618
# Spectral band: 136	Saliency: 16.751197814941406
# Spectral band: 67	Saliency: 16.510656213760377
# Spectral band: 70	Saliency: 15.560031127929687
# Spectral band: 57	Saliency: 15.16754961013794
# Spectral band: 126	Saliency: 14.829623222351074
# Spectral band: 135	Saliency: 14.657360649108886
# Spectral band: 134	Saliency: 14.501569366455078
# Spectral band: 124	Saliency: 14.438427734375
# Spectral band: 115	Saliency: 14.377651166915893
# Spectral band: 72	Saliency: 14.289049434661866
# Spectral band: 23	Saliency: 13.68275785446167
# Spectral band: 58	Saliency: 13.439655017852782
# Spectral band: 117	Saliency: 12.877667999267578
# Spectral band: 69	Saliency: 12.834647130966186
# Spectral band: 133	Saliency: 12.813043785095214
# Spectral band: 65	Saliency: 12.464857292175292
# Spectral band: 132	Saliency: 12.324456167221069
# Spectral band: 43	Saliency: 12.118152475357055
# Spectral band: 122	Saliency: 11.996600437164307
# Spectral band: 118	Saliency: 11.691632080078126
# Spectral band: 125	Saliency: 11.538405513763427
# Spectral band: 63	Saliency: 11.495194149017333
# Spectral band: 42	Saliency: 11.328251457214355
# Spectral band: 62	Saliency: 10.61284589767456
# Spectral band: 114	Saliency: 10.592717933654786
# Spectral band: 20	Saliency: 10.207929468154907
# Spectral band: 121	Saliency: 10.145871591567992
# Spectral band: 27	Saliency: 9.944500064849853
# Spectral band: 116	Saliency: 9.893983602523804
# Spectral band: 0	Saliency: 9.75466799736023
# Spectral band: 52	Saliency: 9.718063974380494
# Spectral band: 25	Saliency: 9.712931680679322
# Spectral band: 39	Saliency: 9.679981422424316
# Spectral band: 53	Saliency: 9.197807168960571
# Spectral band: 129	Saliency: 9.004129362106323
# Spectral band: 64	Saliency: 8.978681612014771
# Spectral band: 51	Saliency: 8.905469608306884
# Spectral band: 17	Saliency: 8.838088274002075
# Spectral band: 22	Saliency: 8.597741508483887
# Spectral band: 61	Saliency: 8.507856702804565
# Spectral band: 21	Saliency: 8.449647188186646
# Spectral band: 59	Saliency: 8.260904598236085
# Spectral band: 41	Saliency: 7.88746337890625
# Spectral band: 130	Saliency: 7.88637056350708
# Spectral band: 68	Saliency: 7.45215630531311
# Spectral band: 55	Saliency: 7.3661217212677
# Spectral band: 11	Saliency: 7.278609895706177
# Spectral band: 6	Saliency: 7.126668977737427
# Spectral band: 93	Saliency: 7.085126686096191
# Spectral band: 127	Saliency: 6.983703565597534
# Spectral band: 37	Saliency: 6.8103502750396725
# Spectral band: 128	Saliency: 6.720466756820679
# Spectral band: 9	Saliency: 6.684951400756836
# Spectral band: 36	Saliency: 6.596350955963135
# Spectral band: 60	Saliency: 6.4660162925720215
# Spectral band: 16	Saliency: 6.277275276184082
# Spectral band: 28	Saliency: 6.1355915546417235
# Spectral band: 120	Saliency: 6.084880304336548
# Spectral band: 14	Saliency: 6.036925840377807
# Spectral band: 7	Saliency: 5.994995164871216
# Spectral band: 18	Saliency: 5.921591472625733
# Spectral band: 54	Saliency: 5.906397867202759
# Spectral band: 12	Saliency: 5.655790853500366
# Spectral band: 75	Saliency: 5.4355696678161625
# Spectral band: 112	Saliency: 5.429162836074829
# Spectral band: 77	Saliency: 5.417812442779541
# Spectral band: 29	Saliency: 5.4152483463287355
# Spectral band: 15	Saliency: 5.296262216567993
# Spectral band: 46	Saliency: 5.282350301742554
# Spectral band: 71	Saliency: 5.2369616508483885
# Spectral band: 49	Saliency: 5.229267644882202
# Spectral band: 19	Saliency: 4.940579795837403
# Spectral band: 105	Saliency: 4.926667022705078
# Spectral band: 89	Saliency: 4.905253934860229
# Spectral band: 38	Saliency: 4.836785316467285
# Spectral band: 111	Saliency: 4.6266326904296875
# Spectral band: 113	Saliency: 4.61143856048584
# Spectral band: 56	Saliency: 4.547005987167358
# Spectral band: 92	Saliency: 4.497577476501465
# Spectral band: 119	Saliency: 4.10015902519226
# Spectral band: 76	Saliency: 3.9886711120605467
# Spectral band: 8	Saliency: 3.7190261363983153
# Spectral band: 48	Saliency: 3.6798548221588137
# Spectral band: 86	Saliency: 3.664660596847534
# Spectral band: 33	Saliency: 3.662096118927002
# Spectral band: 78	Saliency: 3.6443350315093994
# Spectral band: 3	Saliency: 3.5861249923706056
# Spectral band: 90	Saliency: 3.5495184421539308
# Spectral band: 50	Saliency: 3.5039363861083985
# Spectral band: 94	Saliency: 3.201337289810181
# Spectral band: 34	Saliency: 3.173512887954712
# Spectral band: 84	Saliency: 3.1608837604522706
# Spectral band: 109	Saliency: 3.140560579299927
# Spectral band: 83	Saliency: 3.03804874420166
# Spectral band: 91	Saliency: 2.9798357009887697
# Spectral band: 44	Saliency: 2.9620779514312745
# Spectral band: 80	Saliency: 2.9304067611694338
# Spectral band: 45	Saliency: 2.8786057949066164
# Spectral band: 108	Saliency: 2.872196006774902
# Spectral band: 35	Saliency: 2.7696839809417724
# Spectral band: 88	Saliency: 2.7317948818206785
# Spectral band: 13	Saliency: 2.6190250873565675
# Spectral band: 31	Saliency: 2.593766117095947
# Spectral band: 40	Saliency: 2.5329894542694094
# Spectral band: 47	Saliency: 2.370982360839844
# Spectral band: 26	Saliency: 2.367136812210083
# Spectral band: 85	Saliency: 2.267188549041748
# Spectral band: 10	Saliency: 2.263342046737671
# Spectral band: 30	Saliency: 2.0974895477294924
# Spectral band: 79	Saliency: 2.097488355636597
# Spectral band: 82	Saliency: 1.8468833923339845
# Spectral band: 107	Saliency: 1.8000164031982422
# Spectral band: 102	Saliency: 1.6519245147705077
# Spectral band: 32	Saliency: 1.581083059310913
# Spectral band: 100	Saliency: 1.5772363185882567
# Spectral band: 2	Saliency: 1.5177413940429687
# Spectral band: 96	Saliency: 1.3696473121643067
# Spectral band: 106	Saliency: 1.3392588138580321
# Spectral band: 98	Saliency: 1.3240651130676269
# Spectral band: 87	Saliency: 1.2658528804779052
# Spectral band: 4	Saliency: 1.2063591480255127
# Spectral band: 81	Saliency: 1.0443526744842528
# Spectral band: 5	Saliency: 0.9228001117706299
# Spectral band: 101	Saliency: 0.8936944484710694
# Spectral band: 99	Saliency: 0.7734241008758544
# Spectral band: 1	Saliency: 0.7595118999481201
# Spectral band: 103	Saliency: 0.6709122657775879
# Spectral band: 95	Saliency: 0.56583571434021
# Spectral band: 104	Saliency: 0.3873530387878418
# Spectral band: 97	Saliency: 0.3126647472381592
# Spectral band: 110	Saliency: 0.2531705856323242
